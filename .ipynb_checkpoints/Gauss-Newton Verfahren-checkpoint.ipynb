# %%
import sympy as sy
import numpy as np

P0 = [1, 0.5]
P1 = [2, -1]
P2 = [3, 3]
P3 = [4, -7.5]

lamda0 = [[2],[1]] #Startvektor
Pges = [P0, P1, P2, P3] #Alle Punkte eintragen
tolerance = 0.0000000000002
def f(x, l1, l2):
    return sy.sin(l1*x) * sy.exp(l2*x)



i = 0
lTuple = sy.symbols('l(0:len(Pges))')
x = sy.symbols('x')
while (True):
    fLambda = np.empty([len(Pges), 1])
    for j in range(0,len(Pges)):
        try: 
            fLambda[j][0]
            fLambda[j][0] = Pges[j][1] - f(Pges[j][0], lamda0[0][0], lamda0[1][0]).evalf()
        except AttributeError: 
            fLambda[j][0] = Pges[j][1] - f(Pges[j][0], lamda0[0][0], lamda0[1][0])

    jacobi = np.empty([len(Pges), 2])
    for j in range(0,len(Pges)):
        f_l1 = sy.diff(f(Pges[j][0], lTuple[0], lTuple[1]), lTuple[0])
        f_l2 = sy.diff(f(Pges[j][0], lTuple[0], lTuple[1]), lTuple[1])
        try: 
            jacobi[j][0] = f_l1.subs([(lTuple[0], lamda0[0][0]), (lTuple[1], lamda0[1][0])]).evalf()
            jacobi[j][1] = f_l2.subs([(lTuple[0], lamda0[0][0]), (lTuple[1], lamda0[1][0])]).evalf()
        except AttributeError: 
            jacobi[j][0] = f_l1.subs([(lTuple[0], lamda0[0][0]), (lTuple[1], lamda0[1][0])])
            jacobi[j][1] = f_l2.subs([(lTuple[0], lamda0[0][0]), (lTuple[1], lamda0[1][0])])

    if(np.linalg.norm(np.matmul(np.transpose(jacobi), fLambda)) < tolerance):
        raise ValueError("Genauigkeit erreicht")
    else:
        jacobiT = np.transpose(jacobi)
        d = np.matmul(np.matmul(np.linalg.inv(np.matmul(jacobiT, jacobi)), jacobiT), fLambda)
        lamda0 = lamda0 + d
        i+= 1
        print("\u03BB %d: \n" %i, lamda0)
# Out:
# λ 1:
#  [[2.06132601]
#  [0.72359375]]
# λ 2:
#  [[2.16846057]
#  [0.40393371]]
# λ 3:
#  [[ 2.50480399]
#  [-0.02866821]]
# λ 4:
#  [[4.3410268 ]
#  [0.46780066]]
# λ 5:
#  [[4.48692408]
#  [0.4990202 ]]
# λ 6:
#  [[4.43881519]
#  [0.5138692 ]]
# λ 7:
#  [[4.44788286]
#  [0.52082431]]
# λ 8:
#  [[4.4461453 ]
#  [0.52033745]]
# λ 9:
#  [[4.44640938]
#  [0.52046545]]
# λ 10:
#  [[4.44636703]
#  [0.52044794]]
# λ 11:
#  [[4.44637371]
#  [0.52045082]]
# λ 12:
#  [[4.44637265]
#  [0.52045037]]
# λ 13:
#  [[4.44637282]
#  [0.52045044]]
# λ 14:
#  [[4.44637279]
#  [0.52045043]]
# λ 15:
#  [[4.44637279]
#  [0.52045043]]
# λ 16:
#  [[4.44637279]
#  [0.52045043]]
# λ 17:
#  [[4.44637279]
#  [0.52045043]]
# λ 18:
#  [[4.44637279]
#  [0.52045043]]
# λ 19:
#  [[4.44637279]
#  [0.52045043]]
# λ 20:
#  [[4.44637279]
#  [0.52045043]]
# λ 21:
#  [[4.44637279]
#  [0.52045043]]
# λ 22:
#  [[4.44637279]
#  [0.52045043]]
# λ 23:
#  [[4.44637279]
#  [0.52045043]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17220/2287142202.py in <module>
#      39
#      40     if(np.linalg.norm(np.matmul(np.transpose(jacobi), fLambda)) < tolerance):
# ---> 41         raise ValueError("Genauigkeit erreicht")
#      42     else:
#      43         jacobiT = np.transpose(jacobi)
#
# ValueError: Genauigkeit erreicht
