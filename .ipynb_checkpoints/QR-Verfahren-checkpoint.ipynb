# %%
### QR-Transformation ###

import numpy as np

maxiter=12
a=np.array([[4,-8,7,1],[8,-2,-2,2],[7,-2,24,0],[1,2,0,4]])

def qrzerlegung(a):
    q=np.eye(len(a))
    for i in range (0,len(a)-1):
        for j in range (i+1,len(a)):
            if a[j][i]!=0:
                cos=a[i][i]/np.sqrt((a[j][i])**2+(a[i][i])**2)
                sin=a[j][i]/np.sqrt((a[j][i])**2+(a[i][i])**2)
                u=np.eye(len(a))  
                u[i][i]=cos
                u[i][j]=-sin
                u[j][i]=sin
                u[j][j]=cos
                ut=np.transpose(u)
                #print("uT",i+1,j+1,"=\n",ut)
                a=np.dot(ut,a)
                q=np.dot(q,u)
                #print("q=\n",q)
                #print("a=\n",a)
    return q , a

for i in range (0,maxiter):
    q,a= qrzerlegung(a)
    a=np.dot(a,q)
    print("Iteration",i+1,"\n","a=\n",a,"\n","q=\n",q)
    #print(a*q)
# Out:
# Iteration 1
#  a=
#  [[ 1.64705882  6.92451501  0.8660565 ]
#  [-1.54867045  3.64598147 -0.81378254]
#  [ 0.35229417  0.15635996 -0.29304029]]
#  q=
#  [[ 0.48507125  0.38165202  0.78679579]
#  [-0.48507125  0.8660565  -0.12104551]
#  [-0.72760688 -0.32293632  0.60522753]]
# Iteration 2
#  a=
#  [[ 0.1011236   3.38053188  1.23615144]
#  [-5.0085537   5.36527159  0.9689799 ]
#  [-0.07271479  0.0149818  -0.46639519]]
#  q=
#  [[ 0.7198443   0.68826043 -0.09012088]
#  [-0.67684382  0.72476977  0.12880689]
#  [ 0.15396958 -0.03172315  0.98756621]]
# Iteration 3
#  a=
#  [[ 5.40868397  4.91664187 -0.77146082]
#  [-3.50595943  0.04889519  1.21407892]
#  [ 0.00664288  0.0081179  -0.45757916]]
#  q=
#  [[ 0.02018394  0.99963374  0.01802749]
#  [-0.99969093  0.02044028 -0.01415033]
#  [-0.01451363 -0.01773631  0.99973735]]
# Iteration 4
#  a=
#  [[ 3.17770140e+00  6.94375811e+00 -1.32143548e+00]
#  [-1.47634661e+00  2.27938765e+00  5.96747043e-01]
#  [-4.71080544e-04 -6.55383936e-04 -4.57089048e-01]]
#  q=
#  [[ 8.39129107e-01  5.43929809e-01 -1.64471290e-03]
#  [-5.43931319e-01  8.39129494e-01 -6.42580543e-04]
#  [ 1.03060839e-03  1.43381890e-03  9.99998441e-01]]
# Iteration 5
#  a=
#  [[ 9.29232181e-01  6.31637305e+00 -1.44973905e+00]
#  [-2.10371156e+00  4.52805159e+00 -1.59311351e-02]
#  [ 6.14791718e-05 -5.69047453e-06 -4.57283769e-01]]
#  q=
#  [[ 9.06901531e-01  4.21342614e-01  1.16684473e-04]
#  [-4.21342609e-01  9.06901539e-01 -6.79326424e-05]
#  [-1.34444245e-04  1.24440771e-05  9.99999991e-01]]
# Iteration 6
#  a=
#  [[ 2.38351270e+00  1.46133059e+00 -5.71276298e-01]
#  [-6.95878687e+00  3.07374935e+00 -1.33239826e+00]
#  [-1.22237178e-05 -2.21256944e-06 -4.57262052e-01]]
#  q=
#  [[ 4.04049328e-01  9.14737198e-01 -1.52273833e-05]
#  [-9.14737197e-01  4.04049328e-01  2.24980449e-05]
#  [ 2.67324126e-05  4.83873401e-06  1.00000000e+00]]
# Iteration 7
#  a=
#  [[ 4.68653897e+00  6.16995451e+00  1.07541746e+00]
#  [-2.25015851e+00  7.70723856e-01 -9.72200239e-01]
#  [ 7.59883662e-07  1.20310134e-06 -4.57262823e-01]]
#  q=
#  [[ 3.24037571e-01  9.46044213e-01  3.02761968e-06]
#  [-9.46044213e-01  3.24037571e-01 -7.19571954e-07]
#  [-1.66180941e-06 -2.63109373e-06  1.00000000e+00]]
# Iteration 8
#  a=
#  [[ 2.42350751e+00  6.96350933e+00  1.39025773e+00]
#  [-1.45660393e+00  3.03375546e+00 -4.10945203e-01]
#  [-6.68367524e-08 -5.96315597e-08 -4.57262972e-01]]
#  q=
#  [[ 9.01476541e-01  4.32827963e-01 -1.88211108e-07]
#  [-4.32827963e-01  9.01476541e-01 -5.42961890e-08]
#  [ 1.46166990e-07  1.30409771e-07  1.00000000e+00]]
# Iteration 9
#  a=
#  [[ 1.53973407e-01  5.23267013e+00  1.40329023e+00]
#  [-3.18744315e+00  5.30328953e+00  3.63962755e-01]
#  [ 1.08086098e-08 -3.28911846e-09 -4.57262942e-01]]
#  q=
#  [[ 8.57102700e-01  5.15145573e-01  1.65544004e-08]
#  [-5.15145573e-01  8.57102700e-01 -1.83420064e-08]
#  [-2.36376247e-08  7.19305713e-09  1.00000000e+00]]
# Iteration 10
#  a=
#  [[ 5.19273439e+00  2.94403953e+00 -2.95830143e-01]
#  [-5.47607374e+00  2.64528559e-01  1.41921702e+00]
#  [-1.54877125e-09 -1.15076023e-09 -4.57262944e-01]]
#  q=
#  [[ 4.82499814e-02  9.98835291e-01 -2.67712074e-09]
#  [-9.98835291e-01  4.82499814e-02  3.26167524e-09]
#  [ 3.38704737e-09  2.51662690e-09  1.00000000e+00]]
# Iteration 11
#  a=
#  [[ 3.86207423e+00  6.73788377e+00 -1.23338285e+00]
#  [-1.68222951e+00  1.59518871e+00  7.61878713e-01]
#  [ 9.38424369e-11  1.52746199e-10 -4.57262944e-01]]
#  q=
#  [[ 6.88085013e-01  7.25630081e-01  3.83606005e-10]
#  [-7.25630081e-01  6.88085013e-01  8.09325923e-11]
#  [-2.05226420e-10 -3.34044561e-10  1.00000000e+00]]
# Iteration 12
#  a=
#  [[ 1.64962168e+00  6.76159350e+00 -1.43501724e+00]
#  [-1.65851978e+00  3.80764126e+00  2.05956176e-01]
#  [-1.01864064e-11 -3.22873032e-12 -4.57262944e-01]]
#  q=
#  [[ 9.16803646e-01  3.99338297e-01 -2.32432790e-11]
#  [-3.99338297e-01  9.16803646e-01  2.42248029e-12]
#  [ 2.22769121e-11  7.06099271e-12  1.00000000e+00]]

# %%
### QR-Zerlegung ###

import numpy as np

A=np.array([[2,-2,-3],[4,1,-5],[-2,1,2]])
#B=np.array([[14.23188406,1,1,1],[1,-2.225637961781,1,1],[1,1,11.55099424,1],[1,1,1,2.44275967]]) #idk was das hier soll

for i in range(0,len(A)-1):
    for j in range (i+1,len(A)):
        if A[j][i]!=0:
            cos=A[i][i]/np.sqrt((A[j][i])**2+(A[i][i])**2)
            sin=A[j][i]/np.sqrt((A[j][i])**2+(A[i][i])**2)
            u=np.eye(len(A))  
            u[i][i]=cos
            u[i][j]=-sin
            u[j][i]=sin
            u[j][j]=cos
            ut=np.transpose(u)
            print("\nuT %d%d \n %s"% (i+1,j+1,u))
            A=np.dot(ut,A)
            print("A=\n",A)
# Out:
# uT 12
#  [[ 0.4472136  -0.89442719  0.        ]
#  [ 0.89442719  0.4472136   0.        ]
#  [ 0.          0.          1.        ]]
# A=
#  [[ 4.47213595  0.         -5.81377674]
#  [ 0.          2.23606798  0.4472136 ]
#  [-2.          1.          2.        ]]
#
# uT 13
#  [[ 0.91287093  0.          0.40824829]
#  [ 0.          1.          0.        ]
#  [-0.40824829  0.          0.91287093]]
# A=
#  [[ 4.89897949 -0.40824829 -6.12372436]
#  [ 0.          2.23606798  0.4472136 ]
#  [ 0.          0.91287093 -0.54772256]]
#
# uT 23
#  [[ 1.          0.          0.        ]
#  [ 0.          0.9258201  -0.37796447]
#  [ 0.          0.37796447  0.9258201 ]]
# A=
#  [[ 4.89897949e+00 -4.08248290e-01 -6.12372436e+00]
#  [ 0.00000000e+00  2.41522946e+00  2.07019668e-01]
#  [ 0.00000000e+00  5.87376257e-18 -6.76123404e-01]]
